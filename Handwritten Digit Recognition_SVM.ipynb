# %% [markdown]
# Importing Basic Libraries

# %%
import numpy as np
from sklearn.datasets import load_digits

# %% [markdown]
# Load Dataset

# %%
dataset = load_digits()

# %% [markdown]
# Summarize Dataset

# %%
print(dataset.data)
print(dataset.target)

print(dataset.data.shape)
print(dataset.images.shape)

dataimageLength = len(dataset.images)
print(dataimageLength)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# [0 1 2 ... 8 9 8]
# (1797, 64)
# (1797, 8, 8)
# 1797

# %% [markdown]
# Visualize the Dataset

# %%
n=25 #No.of sample out of samples total 1797

import matplotlib.pyplot as plt
plt.gray()
plt.matshow(dataset.images[n])
plt.show()

dataset.images[n]
# Out:
# array([[ 0.,  0., 12.,  8.,  8.,  7.,  0.,  0.],
#        [ 0.,  3., 16., 16., 11.,  7.,  0.,  0.],
#        [ 0.,  2., 14.,  1.,  0.,  0.,  0.,  0.],
#        [ 0.,  5., 14.,  5.,  0.,  0.,  0.,  0.],
#        [ 0.,  2., 15., 16.,  9.,  0.,  0.,  0.],
#        [ 0.,  0.,  0.,  2., 16.,  2.,  0.,  0.],
#        [ 0.,  0.,  4.,  8., 16.,  4.,  0.,  0.],
#        [ 0.,  0., 11., 14.,  9.,  0.,  0.,  0.]])

# %% [markdown]
# segrigate dataset into x-input or (independent variable) and y(out put or dependent variable)

# %%
X=dataset.images.reshape((dataimageLength,-1))
X
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
Y=dataset.target
Y
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %% [markdown]
# splitting dataset into train and test

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (1347, 64)
# (450, 64)

# %% [markdown]
# Training

# %%
from sklearn import svm
model=svm.SVC(kernel='linear')
model.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# predicting,what the digit is from test data

# %%
n=-9
result=model.predict(dataset.images[n].reshape((1,-1)))
plt.imshow(dataset.images[n], cmap=plt.cm.gray_r, interpolation='nearest')
print(result)
print("\n")
plt.axis('off')
plt.title('%i' %result)
plt.show
# Out:
# [4]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# prediction for test data

# %%
Y_pred=model.predict(X_test)
print(np.concatenate((Y_pred.reshape(len(Y_pred),1),Y_test.reshape(len(Y_test),1)),1))
# Out:
# [[2 2]
#  [8 8]
#  [2 2]
#  [6 6]
#  [6 6]
#  [7 7]
#  [1 1]
#  [9 9]
#  [8 8]
#  [5 5]
#  [2 2]
#  [8 8]
#  [6 6]
#  [6 6]
#  [6 6]
#  [6 6]
#  [1 1]
#  [0 0]
#  [5 5]
#  [8 8]
#  [8 8]
#  [7 7]
#  [8 8]
#  [4 4]
#  [7 7]
#  [5 5]
#  [4 4]
#  [9 9]
#  [2 2]
#  [9 9]
#  [4 4]
#  [7 7]
#  [6 6]
#  [8 8]
#  [9 9]
#  [4 4]
#  [3 3]
#  [1 1]
#  [0 0]
#  [1 1]
#  [8 8]
#  [6 6]
#  [7 7]
#  [7 7]
#  [1 1]
#  [0 0]
#  [7 7]
#  [6 6]
#  [2 2]
#  [1 1]
#  [9 9]
#  [6 6]
#  [7 7]
#  [9 9]
#  [0 0]
#  [0 0]
#  [5 5]
#  [1 1]
#  [6 6]
#  [3 3]
#  [0 0]
#  [2 2]
#  [3 3]
#  [4 4]
#  [1 1]
#  [9 9]
#  [2 2]
#  [6 6]
#  [9 9]
#  [1 1]
#  [8 8]
#  [3 3]
#  [5 5]
#  [1 1]
#  [2 2]
#  [8 8]
#  [2 2]
#  [2 2]
#  [9 9]
#  [7 7]
#  [2 2]
#  [3 3]
#  [6 6]
#  [0 0]
#  [5 5]
#  [3 3]
#  [7 7]
#  [5 5]
#  [1 1]
#  [2 2]
#  [9 9]
#  [9 9]
#  [3 3]
#  [1 1]
#  [7 7]
#  [7 7]
#  [4 4]
#  [8 8]
#  [5 5]
#  [8 8]
#  [5 5]
#  [5 5]
#  [2 2]
#  [5 5]
#  [9 9]
#  [0 0]
#  [7 7]
#  [1 1]
#  [4 4]
#  [4 7]
#  [3 3]
#  [4 4]
#  [8 8]
#  [9 9]
#  [7 7]
#  [9 9]
#  [8 8]
#  [2 2]
#  [1 6]
#  [5 5]
#  [2 2]
#  [5 5]
#  [8 8]
#  [4 4]
#  [1 8]
#  [7 7]
#  [0 0]
#  [6 6]
#  [1 1]
#  [5 5]
#  [5 9]
#  [9 9]
#  [9 9]
#  [5 5]
#  [9 9]
#  [9 9]
#  [5 5]
#  [7 7]
#  [5 5]
#  [6 6]
#  [2 2]
#  [8 8]
#  [6 6]
#  [9 9]
#  [6 6]
#  [1 1]
#  [5 5]
#  [1 1]
#  [5 5]
#  [9 9]
#  [9 9]
#  [1 1]
#  [5 5]
#  [3 3]
#  [6 6]
#  [1 1]
#  [8 8]
#  [9 9]
#  [8 8]
#  [7 7]
#  [6 6]
#  [7 7]
#  [6 6]
#  [5 5]
#  [6 6]
#  [0 0]
#  [8 8]
#  [8 8]
#  [9 9]
#  [8 8]
#  [6 6]
#  [1 1]
#  [0 0]
#  [4 4]
#  [1 1]
#  [6 6]
#  [3 3]
#  [8 8]
#  [6 6]
#  [7 7]
#  [4 4]
#  [9 5]
#  [6 6]
#  [3 3]
#  [0 0]
#  [3 3]
#  [3 3]
#  [3 3]
#  [0 0]
#  [7 7]
#  [7 7]
#  [5 5]
#  [7 7]
#  [8 8]
#  [0 0]
#  [7 7]
#  [1 8]
#  [9 9]
#  [6 6]
#  [4 4]
#  [5 5]
#  [0 0]
#  [1 1]
#  [4 4]
#  [6 6]
#  [4 4]
#  [3 3]
#  [3 3]
#  [0 0]
#  [9 9]
#  [5 5]
#  [3 9]
#  [2 2]
#  [1 1]
#  [4 4]
#  [2 2]
#  [1 1]
#  [6 6]
#  [8 8]
#  [9 9]
#  [2 2]
#  [4 4]
#  [9 9]
#  [3 3]
#  [7 7]
#  [6 6]
#  [2 2]
#  [3 3]
#  [3 3]
#  [1 1]
#  [6 6]
#  [9 9]
#  [3 3]
#  [6 6]
#  [3 3]
#  [2 2]
#  [2 2]
#  [0 0]
#  [7 7]
#  [6 6]
#  [1 1]
#  [1 1]
#  [9 9]
#  [7 7]
#  [2 2]
#  [7 7]
#  [8 8]
#  [5 5]
#  [5 5]
#  [7 7]
#  [5 5]
#  [2 2]
#  [3 3]
#  [7 7]
#  [2 2]
#  [7 7]
#  [5 5]
#  [5 5]
#  [7 7]
#  [0 0]
#  [9 9]
#  [1 1]
#  [6 6]
#  [5 5]
#  [9 9]
#  [7 7]
#  [4 4]
#  [3 3]
#  [8 8]
#  [0 0]
#  [3 3]
#  [6 6]
#  [4 4]
#  [6 6]
#  [3 3]
#  [2 2]
#  [6 6]
#  [8 8]
#  [8 8]
#  [8 8]
#  [4 4]
#  [6 6]
#  [7 7]
#  [5 5]
#  [2 2]
#  [4 4]
#  [5 5]
#  [3 3]
#  [2 2]
#  [4 4]
#  [6 6]
#  [9 9]
#  [4 4]
#  [5 5]
#  [4 4]
#  [3 3]
#  [4 4]
#  [6 6]
#  [2 2]
#  [9 9]
#  [0 0]
#  [1 1]
#  [7 7]
#  [2 2]
#  [0 0]
#  [9 9]
#  [6 6]
#  [0 0]
#  [4 4]
#  [2 2]
#  [0 0]
#  [7 7]
#  [9 9]
#  [8 8]
#  [5 5]
#  [4 4]
#  [8 8]
#  [2 2]
#  [8 8]
#  [4 4]
#  [3 3]
#  [7 7]
#  [2 2]
#  [6 6]
#  [9 9]
#  [1 1]
#  [5 5]
#  [1 1]
#  [0 0]
#  [8 8]
#  [2 2]
#  [8 1]
#  [9 9]
#  [5 5]
#  [6 6]
#  [2 8]
#  [2 2]
#  [7 7]
#  [2 2]
#  [1 1]
#  [5 5]
#  [1 1]
#  [6 6]
#  [4 4]
#  [5 5]
#  [0 0]
#  [9 9]
#  [4 4]
#  [1 1]
#  [1 1]
#  [7 7]
#  [0 0]
#  [8 8]
#  [9 9]
#  [0 0]
#  [5 5]
#  [4 4]
#  [3 3]
#  [8 8]
#  [8 8]
#  [6 6]
#  [5 5]
#  [3 3]
#  [4 4]
#  [4 4]
#  [4 4]
#  [8 8]
#  [8 8]
#  [7 7]
#  [0 0]
#  [9 9]
#  [6 6]
#  [3 3]
#  [5 5]
#  [2 2]
#  [3 3]
#  [0 0]
#  [8 8]
#  [8 3]
#  [3 3]
#  [1 1]
#  [3 3]
#  [3 3]
#  [0 0]
#  [0 0]
#  [4 4]
#  [6 6]
#  [0 0]
#  [7 7]
#  [7 7]
#  [6 6]
#  [2 2]
#  [0 0]
#  [4 4]
#  [4 4]
#  [2 2]
#  [3 3]
#  [7 7]
#  [1 8]
#  [9 9]
#  [8 8]
#  [6 6]
#  [8 8]
#  [5 5]
#  [6 6]
#  [2 2]
#  [2 2]
#  [3 3]
#  [1 1]
#  [7 7]
#  [7 7]
#  [8 8]
#  [0 0]
#  [3 3]
#  [3 3]
#  [2 2]
#  [1 1]
#  [5 5]
#  [5 5]
#  [9 9]
#  [1 1]
#  [3 3]
#  [7 7]
#  [0 0]
#  [0 0]
#  [7 7]
#  [0 0]
#  [4 4]
#  [5 5]
#  [8 9]
#  [9 3]
#  [3 3]
#  [4 4]
#  [3 3]
#  [1 1]
#  [8 8]
#  [9 9]
#  [8 8]
#  [3 3]
#  [6 6]
#  [2 2]
#  [1 1]
#  [6 6]
#  [2 2]
#  [1 1]
#  [7 7]
#  [5 5]
#  [5 5]
#  [1 1]
#  [9 9]]

# %% [markdown]
# evaluate model-accurecy score

# %%
from sklearn.metrics import accuracy_score
print("Accuracy of the Model: {0}%".format(accuracy_score(Y_test,Y_pred)*100))
# Out:
# Accuracy of the Model: 97.11111111111111%
